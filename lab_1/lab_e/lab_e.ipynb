# %%
# !g++ lab_e.cpp -o lab_e && ./lab_e
# Out:
# f(9) =9
# f(3) =4
# f(1) =3
# f(2) =0
# f(3) =0

# %% [markdown]
# Hàm này có 3 điều kiện rẽ nhánh để chọn số lớn nhất.
# Nhưng trong bài lại dùng 3 if độc lập, không có else.
#
# - Vì vậy, sẽ có 3 test-case để kiểm tra với mỗi test-case này tương ứng là giá trị lớn nhất của từng nhánh.
# - Tuy nhiên, nếu có trường hợp 2 hoặc 3 số bằng nhau thì sẽ không có nhánh nào thỏa điều kiện → gây ra lỗi logic.
#
# Do đó, số test-case tối thiểu là 4.
#
# ---
#
#  Dữ liệu test case
#
# | Test Case | Input (num1, num2, num3) | Expected Output | Ghi chú |
# |-----------|---------------------------|-----------------|---------|
# | TC1       | (9, 8, 7)                 | 9               | num1 lớn nhất |
# | TC2       | (3, 4, 1)                 | 4               | num2 lớn nhất |
# | TC3       | (1, 2, 3)                | 3          | num3 lớn nhất |
# | TC4       | (2, 2, 1)                 | 0              | 2 số bằng nhau |
# | TC5       | (3, 3, 3)                 | 0            | 3 số bằng nhau |
#
# ---
#
# - Có 3 test-case cơ bản cho từng nhánh.
# - Cần thêm ít nhất 1 test-case để phát hiện lỗi logic (2 số bằng nhau hoặc 3 số bằng nhau).
