# %%
# !g++ lab_d.cpp -o lab_d && ./lab_d
# Out:
# f(5) =10
# f(-3) =-6
# f(0) =0

# %% [markdown]
# - Cấu trúc if–else, nhưng cả 2 nhánh đều return 2 * x.
# - Do đó, điều kiện log(x * x * cos(x)) < 3 * x không ảnh hưởng đến kết quả.
# - hàm chỉ đơn giản là: f3(x) = 2 * x
#
#
# Các test-case
# Vì cả hai nhánh đều cho cùng kết quả, nên chỉ cần 1 test-case tối thiểu để kiểm thử.
# Tuy nhiên, để chắc chắn, ta thử thêm số âm và số 0.
#
# | Test Case | Input (x) | Expected Output | Mục đích kiểm thử |
# |-----------|-----------|-----------------|-------------------|
# | TC1       | 5         | 10              | Số dương |
# | TC2       | -3        | -6              | Số âm |
# | TC3       | 0         | 0               | Giá trị biên |
#
# ---
#
# Kết luận
# - Tối thiểu cần 1 test-case để kiểm tra.
# - Nên dùng 3 test-case (số dương, số âm, số 0) để đảm bảo bao phủ đầy đủ.
# - Như vậy, hàm f3 không cần có rẽ nhánh.
