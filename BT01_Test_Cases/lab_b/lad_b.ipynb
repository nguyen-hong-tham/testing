# %%
# !g++ lab_b.cpp -o lab_b && ./lab_b
# Out:
# f(11) = 22
# f(2) = -2
# f(0) = 0
# f(-3) = -6
# f(10) = -10
# f(-11) = -22

# %% [markdown]
# Theo luồng code trên thì, lỗi error có thể sẽ xuất hiện ở else return 2*x, vì:
# Người lập trình có thể đang hiểu sai về yêu cầu nên viết return kết quả trả về của if và else giống nhau . Vì nếu người lập trình điều muốn x > 10 và x < 0 điều là return x * 2 thì ngay if nên là : (x > 10 ) || (x < 0) return x * 2

# %% [markdown]
# Hàm có 3 điều kiện rẽ nhánh (x > 10), (0 < x <= 10), (x <= 0  ) → do đó có 3 nhánh cần kiểm thử.
#
# - Số test-case tối thiểu = 3.
# #### Các test-case
#
# | Test Case | Input (x) | Expected Output | Mục đích kiểm thử         |
# |-----------|-----------|-----------------|----------------------------|
# | TC1       | 11        | 22              | Kiểm tra nhánh (x > 10)   |
# | TC2       | 2         | -2              | Kiểm tra nhánh (x > 0)   |
# | TC3       | 0        | 0                | Kiểm tra giá trị biên của nhánh (x <= 0) và nhánh (0 < x <= 10 ) để kiểm thử xem kết quả thuộc nhánh nào |
# | TC4       | -3        | -6              | Kiểm tra giá trị nhánh x < 0   |
# | TC5       | 10        | -10             | Kiểm tra giá trị biên của nhánh (x > 10) và nhánh (0 < x <= 10 )  |
# | TC6       | -11        | -22             | Kiểm tra giá trị biên của nhánh else  |
#
# Cần ít nhất 3 test-case để bao phủ.
#
# Nên dùng 6 test-case (thêm giá trị biên và kiểm tra cách xử lý else và if) để kiểm tra tất cả các trường hợp có thể có.
#
# Nhánh else hiện tại có thể chứa lỗi logic error, vì có thể không đúng theo yêu cầu nghiệp vụ. Test-case với x = -11 và x = 11, dù kết quả lần lượt là -22 và 22 nhưng không phải xét về kết quả giống nhau hay không, mà vì cách xử lý ở else và if là 1 sẽ đi vào nhánh này và có thể phát hiện lỗi.
