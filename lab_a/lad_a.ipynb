# %%
# !g++ lab_a.cpp -o lab_a && ./lab_a
# Out:
# f1 (11) = 22
# f1 (9) = -9
# f1 (10) = -10

# %% [markdown]
# Hàm có 1 điều kiện rẽ nhánh (x > 10) → do đó có 2 nhánh cần kiểm thử.
#
# - Số test-case tối thiểu = 2.
# #### Các test-case
#
# | Test Case | Input (x) | Expected Output | Mục đích kiểm thử         |
# |-----------|-----------|-----------------|----------------------------|
# | TC1       | 11        | 22              | Kiểm tra nhánh x > 10   |
# | TC2       | 9         | -9              | Kiểm tra nhánh x < 10   |
# | TC3       | 10        | -10             | Kiểm tra giá trị biên x = 10 |
